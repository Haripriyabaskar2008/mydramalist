# %%
import pandas as pd
data=pd.read_csv("mydramalist.csv")
data.head(10)
print(data)
# Out:
#        id                                                url  \
# 0       1               https://mydramalist.com/1-crows-zero
# 1       2        https://mydramalist.com/2-1-litre-no-namida
# 2       3             https://mydramalist.com/3-crows-zero-2
# 3       4             https://mydramalist.com/4-volcano-high
# 4       5               https://mydramalist.com/5-the-client
# ..    ...                                                ...
# 558  5191  https://mydramalist.com/5191-term-of-validity-...
# 559  5213       https://mydramalist.com/5213-courageous-love
# 560  5215     https://mydramalist.com/5215-the-ugly-duckling
# 561  5220  https://mydramalist.com/5220-resident5-nin-no-...
# 562  5240              https://mydramalist.com/5240-rashomon
#
#                                   title    type        country  \
# 0                     Crows Zero (2007)   Movie         Japan
# 1              1 Litre no Namida (2005)   Drama         Japan
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           563 non-null    int64
#  1   url          563 non-null    object
#  2   title        563 non-null    object
#  3   type         563 non-null    object
#  4   country      563 non-null    object
#  5   director     323 non-null    object
#  6   alsoknownas  563 non-null    object
#  7   episodes     321 non-null    float64
#  8   score        563 non-null    object
#  9   aired        321 non-null    object
#  10  duration     545 non-null    object
#  11  genres       551 non-null    object
#  12  tags         399 non-null    object
#  13  mainrole     548 non-null    object
#  14  supportrole  495 non-null    object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 37.5+ KB

# %%
data.isnull().sum()
# Out:
# id               0
# url              0
# title            0
# type             0
# country          0
# director       240
# alsoknownas      0
# episodes       242
# score            0
# aired          242
# duration        18
# genres          12
# tags           164
# mainrole        15
# supportrole     68
# dtype: int64
